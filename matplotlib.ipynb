# %% [markdown]
# # Matplotlib Tutorial

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
plt.plot([1,2,3,4],[-2,6,3,4])
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "bo")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "ro")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "go")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "yo")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "b+")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "b*")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "b-")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "r-")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
plt.plot([1,2,3,4],[-2,6,3,4] , "g-")
plt.ylabel("Hey Mahdi")
plt.xlabel("Hey Wife")
plt.show()

# %%
x = np.arange(10,50,5)
y = np.arange(10,50,5)

# %%
x
# Out:
# array([10, 15, 20, 25, 30, 35, 40, 45])

# %%
y
# Out:
# array([10, 15, 20, 25, 30, 35, 40, 45])

# %%
plt.plot(x , y)
plt.ylabel("Mahdi")
plt.xlabel("Zahra")
# Out:
# Text(0.5, 0, 'Zahra')

# %%
t = np.arange(0 , 5 , 0.3)
plt.plot(t , t)

# %%
t
# Out:
# array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. , 3.3, 3.6,
#        3.9, 4.2, 4.5, 4.8])

# %%
plt.plot(t , t*2)

# %%
plt.plot(t , t**2)

# %%
plt.plot(t , t**2 , "r--")

# %%
plt.plot(t , t**2 , "b--" , t , t*3 , "r--" , t , t , "g--")

# %%
data = {
    "a" : np.arange(1, 101, 0.5),
    "b" : np.random.randint(0, 200 , 200),
    "c" : np.random.randn(200)
}

# %% [markdown]
# ### scater یا اسکتر کردن در ماشین لرنینگ بسیار پر کاربرد است . اسکتر به معنای پخش کردن است یعنی لزومی نداره حتما برام یه خط بسازی با نقطه ها فقط مکان نقطه ها رو برام مشخص کن

# %%
plt.scatter(data["a"] , data["b"])

# %%
plt.scatter(data["a"] , data["c"])
